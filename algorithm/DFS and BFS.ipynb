# %%
# 1260 => 개느림 DFS에서 중복 떄문 188
from collections import deque
import sys
input = sys.stdin.readline
print = sys.stdout.write

def DFS(graph, start_node):
    visited = [0] * (N+1)
    visited[start_node] = 1
    print(str(start_node) + " ")
    for i in graph[start_node]:
        if visited[i] == 0:
            aDFS(graph, visited, i)

def aDFS(graph, visited, node):
    visited[node] = 1
    print(str(node) + " ")
    for i in graph[node]:
        if visited[i] == 0:
            aDFS(graph, visited, i)

def BFS(graph, start_node):
    visited = [0] * (N+1)
    need_visit = deque([start_node])
    visited[start_node] = 1
    
    while len(need_visit) != 0:
        node = need_visit.popleft()
        print(str(node) + " ")
        for i in graph[node]:
            if visited[i] == 0:
                visited[i] = 1
                need_visit.append(i)
    
N, M, start_node = map(int, input().split())

graph = [[] for _ in range(N+1)]

for _ in range(M):
    i, j = map(int, input().split())
    graph[i].append(j)
    graph[j].append(i)
for i in range(1, N+1):
    graph[i].sort()
    
DFS(graph, start_node)
print("\n")
BFS(graph, start_node)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-243d5837eb33> in <module>
#      33                 need_visit.append(i)
#      34
# ---> 35 N, M, start_node = map(int, input().split())
#      36
#      37 graph = [[] for _ in range(N+1)]
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
# 1280 DFS 재귀를 중복없이 간단하게 하였더니 172
from collections import deque
import sys
input = sys.stdin.readline
print = sys.stdout.write

def DFS(graph, start_node):
    visited = [0] * (N+1)
    aDFS(graph, visited, start_node)

def aDFS(graph, visited, node):
    visited[node] = 1
    print(str(node) + " ")
    for i in graph[node]:
        if visited[i] == 0:
            aDFS(graph, visited, i)

def BFS(graph, start_node):
    visited = [0] * (N+1)
    need_visit = deque([start_node])
    visited[start_node] = 1
    
    while len(need_visit) != 0:
        node = need_visit.popleft()
        print(str(node) + " ")
        for i in graph[node]:
            if visited[i] == 0:
                visited[i] = 1
                need_visit.append(i)
    
N, M, start_node = map(int, input().split())

graph = [[] for _ in range(N+1)]

for _ in range(M):
    i, j = map(int, input().split())
    graph[i].append(j)
    graph[j].append(i)
for i in range(1, N+1):
    graph[i].sort()
    
DFS(graph, start_node)
print("\n")
BFS(graph, start_node)

# %%
# 1260 DFS를 비재귀로? => 이런 양방향에서는 아래와 같은 비재귀는 쓸 수 없다. 재귀는 사용 가능 먼저 강탈하니까
from collections import deque
import sys
input = sys.stdin.readline
print = sys.stdout.write

def DFS(graph, start_node):
    visited = [0] * (N+1)
    stack = list()
    stack.append(start_node)
    visited[start_node] = 1
    while len(stack) != 0:
        node = stack.pop()
        print(str(node) + " ")
        for i in reversed(graph[node]):
            if visited[i] == 0:
                visited[i] = 1
                stack.append(i)



def BFS(graph, start_node):
    visited = [0] * (N+1)
    need_visit = deque([start_node])
    visited[start_node] = 1
    
    while len(need_visit) != 0:
        node = need_visit.popleft()
        print(str(node) + " ")
        for i in graph[node]:
            if visited[i] == 0:
                visited[i] = 1
                need_visit.append(i)
    
N, M, start_node = map(int, input().split())

graph = [[] for _ in range(N+1)]

for _ in range(M):
    i, j = map(int, input().split())
    graph[i].append(j)
    graph[j].append(i)
for i in range(1, N+1):
    graph[i].sort()
    
DFS(graph, start_node)
print("\n")
BFS(graph, start_node)
